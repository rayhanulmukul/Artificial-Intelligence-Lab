# %%
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
import numpy as np

# %%
from tensorflow.keras.datasets.fashion_mnist import load_data
(X_train, y_train), (X_test, y_test) = load_data()
X_train = np.expand_dims(X_train, axis = -1)
X_test = np.expand_dims(X_test, axis = -1)
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

print(X_train.shape)
print(y_train.shape)
# Out:
# (60000, 28, 28, 1)
# (60000, 10)

# %% [markdown]
# ## Building a FCNN

# %%
def make_fcnn():
  input = Input((28, 28, 1), name='Input Layer')
  x = Flatten(name='Flatten-Layer')(input)
  x = Dense(32, activation='relu', name='Hidden-1')(x)
  x = Dense(64, activation='relu', name='Hidden-2')(x)
  x = Dense (128, activation='relu', name='Hidden-3')(x)
  x = Dense(64, activation='relu', name='Hidden-4')(x)
  x = Dense(32, activation='relu', name='Hidden-5')(x)
  x = Dense(26, activation='relu', name='Hidden-6')(x)
  output = Dense(10, activation='softmax', name='Output-Layer')(x)

  return Model(input, output, name='FCNN')

# %%
fcnn = make_fcnn()
fcnn.summary()
# Out:
# Model: "FCNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input Layer (InputLayer)             │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Flatten-Layer (Flatten)              │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-1 (Dense)                     │ (None, 32)                  │          25,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-2 (Dense)                     │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-3 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-4 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-5 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-6 (Dense)                     │ (None, 26)                  │             858 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output-Layer (Dense)                 │ (None, 10)                  │             270 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 47,016 (183.66 KB)
#  Trainable params: 47,016 (183.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Building a CNN

# %%
def make_cnn():
  input = Input((28, 28, 1), name='Input Layer')
  x = Conv2D(32, (3, 3), activation='relu', name='Hidden-1')(input)
  x = MaxPooling2D((2, 2), name='Pooling-1')(x)
  x = Conv2D(64, (3, 3), activation='relu', name='Hidden-2')(x)
  x = MaxPooling2D((2, 2), name='Pooling-2')(x)
  x = Flatten(name='Flatten-Layer')(x)
  x = Dense (128, activation='relu', name='Hidden-3')(x)
  x = Dense(64, activation='relu', name='Hidden-4')(x)
  x = Dense(32, activation='relu', name='Hidden-5')(x)
  x = Dense(26, activation='relu', name='Hidden-6')(x)
  output = Dense(10, activation='softmax', name='Output-Layer')(x)

  return Model(input, output, name='FCNN')

# %%
cnn = make_cnn()
cnn.summary()
# Out:
# Model: "FCNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input Layer (InputLayer)             │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-1 (Conv2D)                    │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pooling-1 (MaxPooling2D)             │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-2 (Conv2D)                    │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pooling-2 (MaxPooling2D)             │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Flatten-Layer (Flatten)              │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-3 (Dense)                     │ (None, 128)                 │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-4 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-5 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Hidden-6 (Dense)                     │ (None, 26)                  │             858 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output-Layer (Dense)                 │ (None, 10)                  │             270 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 235,208 (918.78 KB)
#  Trainable params: 235,208 (918.78 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train and Evaluate

# %%
def train_and_evaluate(model, name, validation_split=0.0):
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  print(f"Training {name}...")
  print(X_train.shape, y_train.shape)
  model.fit(X_train, y_train, epochs=10, batch_size=256, validation_split=validation_split)
  print(f"Trained {name}.")

  test_loss, test_accuracy = model.evaluate(X_test, y_test)
  print(f"Loss: {test_loss}")
  print(f"Accuracy: {test_accuracy}")

  return model.predict(X_test)

# %% [markdown]
# ## Training FCNN without validation set.

# %%
fcnn_pred_y = train_and_evaluate(fcnn, "FCNN")
# Out:
# Training FCNN...
# (60000, 28, 28, 1) (60000, 10)
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5036 - loss: 3.2437
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7833 - loss: 0.6003
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8188 - loss: 0.5044
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8313 - loss: 0.4561
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8407 - loss: 0.4377
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8510 - loss: 0.4099
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8560 - loss: 0.3915
# Epoch 8/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8581 - loss: 0.3878
# Epoch 9/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8633 - loss: 0.3724
# Epoch 10/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8682 - loss: 0.3553
# Trained FCNN.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8510 - loss: 0.4138
# Loss: 0.42232298851013184
# Accuracy: 0.8499000072479248
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
print("TestY \t\t PredY")
print("===== \t\t =====")
for i in range(10):
  print(np.argmax(y_test[i]), " \t\t ", np.argmax(fcnn_pred_y[i]))
# Out:
# TestY 		 PredY
# ===== 		 =====
# 9  		  9
# 2  		  2
# 1  		  1
# 1  		  1
# 6  		  6
# 1  		  1
# 4  		  4
# 6  		  6
# 5  		  5
# 7  		  7

# %% [markdown]
# ## Training FCNN with validation set.

# %%
fcnn_pred_y = train_and_evaluate(fcnn, "FCNN", 0.2)
# Out:
# Training FCNN...
# (60000, 28, 28, 1) (60000, 10)
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8642 - loss: 0.3750 - val_accuracy: 0.8611 - val_loss: 0.3666
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8701 - loss: 0.3524 - val_accuracy: 0.8539 - val_loss: 0.3928
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8710 - loss: 0.3481 - val_accuracy: 0.8665 - val_loss: 0.3710
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8754 - loss: 0.3367 - val_accuracy: 0.8703 - val_loss: 0.3675
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8749 - loss: 0.3378 - val_accuracy: 0.8705 - val_loss: 0.3681
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8774 - loss: 0.3293 - val_accuracy: 0.8715 - val_loss: 0.3562
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8822 - loss: 0.3176 - val_accuracy: 0.8702 - val_loss: 0.3632
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8852 - loss: 0.3046 - val_accuracy: 0.8657 - val_loss: 0.3747
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8862 - loss: 0.3116 - val_accuracy: 0.8710 - val_loss: 0.3701
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8885 - loss: 0.3000 - val_accuracy: 0.8671 - val_loss: 0.3804
# Trained FCNN.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8513 - loss: 0.4158
# Loss: 0.41935986280441284
# Accuracy: 0.8511999845504761
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
print("TestY \t\t PredY")
print("===== \t\t =====")
for i in range(10):
  print(np.argmax(y_test[i]), " \t\t ", np.argmax(fcnn_pred_y[i]))
# Out:
# TestY 		 PredY
# ===== 		 =====
# 9  		  9
# 2  		  2
# 1  		  1
# 1  		  1
# 6  		  6
# 1  		  1
# 4  		  4
# 6  		  6
# 5  		  5
# 7  		  7

# %% [markdown]
# ## Training CNN without validation set.

# %%
cnn_pred_y = train_and_evaluate(cnn, "CNN")
# Out:
# Training CNN...
# (60000, 28, 28, 1) (60000, 10)
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 51s 205ms/step - accuracy: 0.5800 - loss: 1.5272
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 52s 220ms/step - accuracy: 0.8454 - loss: 0.4478
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 78s 204ms/step - accuracy: 0.8751 - loss: 0.3657
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 85s 219ms/step - accuracy: 0.8861 - loss: 0.3233
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 80s 208ms/step - accuracy: 0.8981 - loss: 0.2845
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 81s 204ms/step - accuracy: 0.9073 - loss: 0.2584
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 83s 207ms/step - accuracy: 0.9110 - loss: 0.2514
# Epoch 8/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 81s 204ms/step - accuracy: 0.9172 - loss: 0.2292
# Epoch 9/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 84s 210ms/step - accuracy: 0.9227 - loss: 0.2130
# Epoch 10/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 80s 203ms/step - accuracy: 0.9280 - loss: 0.1962
# Trained CNN.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9027 - loss: 0.2975
# Loss: 0.28723299503326416
# Accuracy: 0.9045000076293945
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step

# %%
print("TestY \t\t PredY")
print("===== \t\t =====")
for i in range(10):
  print(np.argmax(y_test[i]), " \t\t ", np.argmax(cnn_pred_y[i]))
# Out:
# TestY 		 PredY
# ===== 		 =====
# 9  		  9
# 2  		  2
# 1  		  1
# 1  		  1
# 6  		  6
# 1  		  1
# 4  		  4
# 6  		  6
# 5  		  5
# 7  		  7

# %% [markdown]
# ## Training CNN with validation set.

# %%
cnn_pred_y = train_and_evaluate(cnn, "CNN", 0.2)
# Out:
# Training CNN...
# (60000, 28, 28, 1) (60000, 10)
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 50s 255ms/step - accuracy: 0.9237 - loss: 0.2081 - val_accuracy: 0.9273 - val_loss: 0.1963
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 42s 221ms/step - accuracy: 0.9331 - loss: 0.1810 - val_accuracy: 0.9250 - val_loss: 0.2016
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 81s 214ms/step - accuracy: 0.9404 - loss: 0.1639 - val_accuracy: 0.9190 - val_loss: 0.2246
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 43s 223ms/step - accuracy: 0.9448 - loss: 0.1460 - val_accuracy: 0.9236 - val_loss: 0.2145
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 80s 213ms/step - accuracy: 0.9514 - loss: 0.1330 - val_accuracy: 0.9167 - val_loss: 0.2377
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 41s 216ms/step - accuracy: 0.9529 - loss: 0.1284 - val_accuracy: 0.9223 - val_loss: 0.2271
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 42s 223ms/step - accuracy: 0.9518 - loss: 0.1292 - val_accuracy: 0.9210 - val_loss: 0.2429
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 80s 214ms/step - accuracy: 0.9588 - loss: 0.1122 - val_accuracy: 0.9199 - val_loss: 0.2581
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 41s 212ms/step - accuracy: 0.9631 - loss: 0.1013 - val_accuracy: 0.9213 - val_loss: 0.2458
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 43s 224ms/step - accuracy: 0.9658 - loss: 0.0939 - val_accuracy: 0.9205 - val_loss: 0.2675
# Trained CNN.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9028 - loss: 0.3926
# Loss: 0.3704696595668793
# Accuracy: 0.906499981880188
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step

# %%
print("TestY \t\t PredY")
print("===== \t\t =====")
for i in range(10):
  print(np.argmax(y_test[i]), " \t\t ", np.argmax(cnn_pred_y[i]))
# Out:
# TestY 		 PredY
# ===== 		 =====
# 9  		  9
# 2  		  2
# 1  		  1
# 1  		  1
# 6  		  6
# 1  		  1
# 4  		  4
# 6  		  6
# 5  		  5
# 7  		  7
